# %% [markdown]
# ## MTH9855 Asset Allocation and Portfolio Management
#
# * HW 01
# * Author: **Hongchao Pan**

# %%
# Load the library
library(repr)

# %% [markdown]
# ### Problem 1.1

# %% [markdown]
# * In probability theory, if X is a random variable, then we have Jensen's inequality stats that $\phi (\mathbb{E}(X)) \le \mathbb{E}(\phi(X))$ if and only if $\phi$ is a convex function. Or we can state this as: $\mathbb{E}(\phi(X)) \le \phi (\mathbb{E}(X))$ if and only if $\phi$ is a concave function.
#
#
# * Let $\phi \stackrel{d}{=} u, X\stackrel{d}{=}w+ \tilde{z}$, then we have:
#
# $$
# \mathbb{E}(u(w+\tilde{z})) \le u(\mathbb{E}(w+\tilde{z}))=u(w+\mathbb{E}(\tilde{z}))
# $$
#
# if and only if $u$ is a concave function.

# %% [markdown]
# ### Problem 1.2

# %% [markdown]
# * From Lecture 1, we have the risk premium defined by:
#
# $$
# \mathbb{E}(u(w+\tilde{z}))=u(w-\Pi)
# $$
#
# * Plug the utility function into above equation, we have:
#
# $$
# \frac{-\exp(-a(w-\Pi))}{a}=\frac{-\mathbb{E}[\exp(-a(w-\Pi))]}{a}
# $$
#
# $\Rightarrow$
#
# \begin{eqnarray*}
# \Pi &=& w+\frac{\log[\mathbb{E}(\exp(-a(w+\tilde{z}))]}{a}\\
# &=& w+ \frac{1}{a}\log\exp(-aw) +\frac{1}{a}\log\exp(-a\tilde{z})\\
# &=& w- w + \frac{1}{2}a\sigma^2\\
# &=& \frac{1}{2}\sigma^2 A(w)
# \end{eqnarray*}
#
# As $A(w)=-\frac{u''}{u'}=a$

# %% [markdown]
# * With given condition in the question, $u(w)=-\exp(-aw)/a$, we can compute the $\mathbb{E}[u(\tilde{w})]$ as:

# %% [markdown]
# \begin{eqnarray*}
# \mathbb{E}\left[u(\tilde{w})\right] &=& \int_{-\infty}^{\infty}-\frac{1}{a}e^{-a\tilde{w}}
# \frac{1}{\sigma \sqrt{2\pi}}e^{-\frac{(\tilde{w}-\mu)^2}{2\sigma^2}}d\tilde{w}\\
# &=& -\frac{1}{a}\int_{-\infty}^{\infty}\frac{1}{\sigma\sqrt{2\pi}}e^{(\tilde{w}-(\mu-a\sigma))^2}e^{-\frac{\mu^2-(\mu-a\sigma^2)^2}{2\sigma^2}}d(\tilde{w}-(\mu-a\sigma))^2)\\
# &=& -\frac{1}{a}e^{-\frac{\mu^2-(\mu-a\sigma^2)^2}{2\sigma^2}}\\
# &=& -\frac{1}{a}e^{-a(\mu-\frac{1}{2}a\sigma^2)}\\
# &=& u(\mu-\frac{1}{2}a\sigma^2)
# \end{eqnarray*}

# %% [markdown]
# ### Problem 1.3

# %% [markdown]
# * From lecture 1, if agent $v$ is more risk-averse than agent $u$, we have: $\Pi_v \ge \Pi_u$.
#
#
# * From equation (1) in lecture 1, we know: $\Pi \sim \frac{1}{2}\sigma^2 A(w)$. Then we have: $A_v(w) \ge A_u(w)$, i.e., (a) and (b) are equivalent.
#
#
# * Given $v(w)=\phi(u(w))$. As $v$ and $u$ are strictly increasing function, we have: $u'>0, v'>0$.
#
#
# * $v(w)=\phi(u(w)) \rightarrow v'=\phi'(u)u'>0 \rightarrow \phi'>0$.
#
#
# * Given the eqaution, we can compute the $A(w)$ of agent $v$ and ageng $u$ as:
#
# \begin{eqnarray*}
# A_v(w)&=&\frac{-v{''}}{v'}\\
# &=& -\frac{\phi{''}(u')^2 + \phi' u{''}}{\phi' u'}\\
# &=&-\frac{\phi'' u'}{\phi'}-\frac{u''}{u'}\\
# &=&-\frac{\phi'' u'}{\phi'} +A_u(w)
# \end{eqnarray*}
#
# $\Rightarrow$
#
# $$
# A_v(w)-A_u(w) = -\frac{\phi'' u'}{\phi'}
# $$

# %% [markdown]
# * If (a) or (b) holds, we have $A_v(w) \ge A_u(w)$, then we have $\phi'' <0$ with $\phi'>0$

# %% [markdown]
# * Then we have (a), (b), and (c) are equivalent.

# %% [markdown]
# ### Problem 1.4

# %% [markdown]
# * From lecture 1, we have the risk premium is defined by:
#
# $$
# \mathbb{E}[u(w+\tilde{z})]=u(w-\Pi)
# $$

# %% [markdown]
# * Then for function $v$, we can compute the risk premium as:
#
# \begin{eqnarray*}
# \mathbb{E}[v(w+\tilde{z})] &=& \mathbb{E}[a+bu(w+\tilde{z})]\\
# &=&a+b\mathbb{E}[u(w+\tilde{z})]\\
# &=& a+ bu(w-\Pi)\\
# &=&v(w-\Pi)
# \end{eqnarray*}

# %% [markdown]
# * This indicates that $v$ and $u$ make the same decisions with same risk $\tilde{z}$ and same risk premium $\Pi$.

# %% [markdown]
# ### Problem 1.5
#
# #### Answer of (a):

# %% [markdown]
# * With $h'r=\sum_i h_i r_i$, we have:
#
# \begin{eqnarray*}
# \mathbb{E}[h'r] &=& \frac{1}{n} \sum_i \mathbb{E}[r_i]\\
# &=& \beta \mathbb{E}[r_M] + \frac{1}{n}\sum_i E[\epsilon_i]
# \end{eqnarray*}

# %% [markdown]
# \begin{eqnarray*}
# \mathbb{V}[h'r] &=& \mathbb{V}[ \sum_i \frac{1}{n} (\beta r_M + \epsilon_i) ]\\
#       &=& \mathbb{V}[ \beta r_M + \frac{1}{n} \sum_i \epsilon_i ]\\
#       &=& \beta^2 \sigma_M^2 + \mathbb{V}[ \frac{1}{n} \sum_i \epsilon_i ]\\
#       &=& \beta^2 \sigma_M^2 + \frac{1}{n^2} \sum_i \sigma_i^2
# \end{eqnarray*}

# %% [markdown]
# * As $\mathbb{V}(h'r)=f(\beta,\sigma_M^2)+g(\sigma_1^2,\dots,\sigma_n^2)$, we then have:
#
# $$
# f=\beta^2 \sigma_M^2\\
# g=\frac{1}{n^2}\sum_i\sigma_i^2
# $$

# %% [markdown]
# #### Answer of (b):

# %%
# Define a function to compute the fraction f/(f+g)
beta <- 0.5
sigma_M <- 0.2
sigma_i <- 0.03

fracFunc <- function(n){
    # Only input is n
    f <- beta^2 * sigma_M^2
    g <- (n* sigma_i^2)*1.0/(n^2)
    
    return (f*1.0/(f+g))
}

# %%
# Compute the fraction function
N <- 2:30
fracRes <- fracFunc(N)
fracRes
# Out:
#  [1] 0.9569378 0.9708738 0.9779951 0.9823183 0.9852217 0.9873061 0.9888752
#  [8] 0.9900990 0.9910803 0.9918846 0.9925558 0.9931245 0.9936125 0.9940358
# [15] 0.9944065 0.9947338 0.9950249 0.9952855 0.9955202 0.9957326 0.9959258
# [22] 0.9961022 0.9962640 0.9964129 0.9965504 0.9966777 0.9967960 0.9969062
# [29] 0.9970090

# %%
# Plot the fraction w.r.t. to N
options(repr.plot.height=4,repr.plot.width=6)
plot(N,fracRes,col="blue",xlab="N",ylab="Fraction Function",
    main="Fraction function result vs N")
# Out:
# Plot with title “Fraction function result vs N”

# %% [markdown]
# #### Answer of (c):

# %% [markdown]
# * With $\mathbb{E}[r_M]=0.07, \mathbb{E}[\epsilon_i]=1.5\sigma_i$ or $\mathbb{E}[\epsilon_i]=2\sigma_i$, we have:

# %%
# Define a function to compute the sharpe ratio
beta <- 0.5
sigma_M <- 0.2
sigma_i <- 0.03
E_rm <- 0.07
E_ei1 <- 1.5*sigma_i
E_ei2 <- 2.0*sigma_i

SharpeRatio <- function(n,E_ei){
    E <- beta * E_rm + (n*E_ei)/n -0.01
    Sigma <- sqrt((beta^2 * sigma_M^2) + (n* sigma_i^2)*1.0/(n^2))
    
    return (E*1.0/Sigma)
}

# %% [markdown]
# * If $\mathbb{E}[\epsilon_i]=1.5\sigma_i$

# %%
# Compute the Sharpe ratio w.r.t. N
N <- 2:30
SharpeRatio_res1 <- SharpeRatio(N,E_ei1)
SharpeRatio_res1
# Out:
#  [1] 0.6847624 0.6897305 0.6922554 0.6937838 0.6948083 0.6955429 0.6960954
#  [8] 0.6965260 0.6968711 0.6971538 0.6973897 0.6975894 0.6977608 0.6979094
# [15] 0.6980395 0.6981544 0.6982565 0.6983480 0.6984303 0.6985048 0.6985726
# [22] 0.6986344 0.6986912 0.6987434 0.6987916 0.6988362 0.6988777 0.6989163
# [29] 0.6989524

# %% [markdown]
# * If $\mathbb{E}[\epsilon_i]=2\sigma_i$

# %%
SharpeRatio_res2 <- SharpeRatio(N,E_ei2)
SharpeRatio_res2
# Out:
#  [1] 0.8314972 0.8375299 0.8405959 0.8424517 0.8436958 0.8445878 0.8452587
#  [8] 0.8457816 0.8462006 0.8465439 0.8468303 0.8470729 0.8472810 0.8474614
# [15] 0.8476194 0.8477589 0.8478829 0.8479940 0.8480939 0.8481844 0.8482667
# [22] 0.8483418 0.8484107 0.8484741 0.8485327 0.8485869 0.8486372 0.8486841
# [29] 0.8487279

# %%
# Plot the two Sharpe ratio
options(repr.plot.height=4,repr.plot.width=6)
yrange <- c(0.6,0.9)
plot(N,SharpeRatio_res1,col="red",ylab="Computed Sharpe Ratio",xlab="N",
     main="Sharpe ratio w.r.t. N",type='o',ylim=yrange)
lines(N,SharpeRatio_res2,type='o',col="blue")
legend('topleft', c("Sharpe ratio = 1.5","Sharpe ratio = 2") , lty=1,bty='n', 
       y.intersp=1.5,cex=1,col=c("red", "blue") )
# Out:
# Plot with title “Sharpe ratio w.r.t. N”

# %% [markdown]
# ### Answer of (d):

# %% [markdown]
# * If $\beta=0, \sigma_i=0.1$, we can compute the new computed Sharpe ratio as:

# %%
# Define a funciton  to compute the new Sharpe ratio
# Define a function to compute the sharpe ratio
beta <- 0
sigma_M <- 0.2
sigma_i <- 0.1
E_rm <- 0.07
E_ei1 <- 1.5*sigma_i
E_ei2 <- 2.0*sigma_i

SharpeRatio_new <- function(n,E_ei){
    E <- beta * E_rm + (n*E_ei)/n -0.01
    Sigma <- sqrt((beta^2 * sigma_M^2) + (n* sigma_i^2)*1.0/(n^2))
    
    return (E*1.0/Sigma)
}

# %%
# Compute the new Sharpe ratio
N <- 2:30
SharpeRatio_new_res1 <- SharpeRatio_new(N,E_ei1)
SharpeRatio_new_res2 <- SharpeRatio_new(N,E_ei2)

# %%
SharpeRatio_new_res1
# Out:
#  [1] 1.979899 2.424871 2.800000 3.130495 3.429286 3.704052 3.959798 4.200000
#  [9] 4.427189 4.643275 4.849742 5.047772 5.238320 5.422177 5.600000 5.772348
# [17] 5.939697 6.102459 6.260990 6.415606 6.566582 6.714164 6.858571 7.000000
# [25] 7.138627 7.274613 7.408104 7.539231 7.668116

# %%
SharpeRatio_new_res2
# Out:
#  [1]  2.687006  3.290897  3.800000  4.248529  4.654031  5.026927  5.374012
#  [8]  5.700000  6.008328  6.301587  6.581793  6.850547  7.109149  7.358668
# [15]  7.600000  7.833901  8.061017  8.281908  8.497058  8.706894  8.911790
# [22]  9.112080  9.308061  9.500000  9.688137  9.872690 10.053855 10.231813
# [29] 10.406729

# %%
# Plot the comparison
options(repr.plot.height=5,repr.plot.width=8)
yrange <- c(0.6,10)
plot(N,SharpeRatio_res1,col="red",ylab="Computed Sharpe Ratio",xlab="N",
     main="Sharpe ratio w.r.t. N",type='o',ylim=yrange)
lines(N,SharpeRatio_res2,type='o',col="blue")
lines(N,SharpeRatio_new_res1,type='o',col="orange")
lines(N,SharpeRatio_new_res2,type='o',col="green")
legend('topleft', c("Sharpe ratio = 1.5","Sharpe ratio = 2","Sharpe ratio = 1.5 New","Sharpe ratio = 2 New") , 
       lty=1,bty='n', 
       y.intersp=1.5,cex=1,col=c("red", "blue","orange","green") )
# Out:
# Plot with title “Sharpe ratio w.r.t. N”

# %% [markdown]
# * From the figure above, we can conclude that the investment method in (d) is better than (c).
